# %%
import os

base = r"C:\Projects\RoadGuard-AI\data\raw"

for split in ["train", "valid", "test"]:
    imgs = len(os.listdir(f"{base}/{split}/images"))
    lbls = len(os.listdir(f"{base}/{split}/labels"))
    print(f"{split:6} → images: {imgs:5} | labels: {lbls:5}")
# Out:
# train  → images: 18771 | labels: 18771
# valid  → images:  3921 | labels:  3921
# test   → images:  3968 | labels:  3968
